# %%
import numpy as np

import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50

training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# --2021-03-03 01:31:17--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.15.112, 172.217.2.112, 172.253.62.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.15.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2021-03-03 01:31:17 (107 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 24)                3096
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 29,489
# Trainable params: 29,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 36s 5ms/step - loss: 0.5594 - accuracy: 0.6862 - val_loss: 0.4094 - val_accuracy: 0.8186
# Epoch 2/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3582 - accuracy: 0.8406 - val_loss: 0.3950 - val_accuracy: 0.8211
# Epoch 3/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3172 - accuracy: 0.8585 - val_loss: 0.4139 - val_accuracy: 0.8091
# Epoch 4/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2762 - accuracy: 0.8814 - val_loss: 0.3983 - val_accuracy: 0.8240
# Epoch 5/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2483 - accuracy: 0.8968 - val_loss: 0.4195 - val_accuracy: 0.8155
# Epoch 6/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2127 - accuracy: 0.9142 - val_loss: 0.4493 - val_accuracy: 0.8162
# Epoch 7/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1839 - accuracy: 0.9291 - val_loss: 0.4932 - val_accuracy: 0.8122
# Epoch 8/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1546 - accuracy: 0.9430 - val_loss: 0.5708 - val_accuracy: 0.8132
# Epoch 9/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1298 - accuracy: 0.9559 - val_loss: 0.5961 - val_accuracy: 0.8097
# Epoch 10/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1065 - accuracy: 0.9644 - val_loss: 0.6714 - val_accuracy: 0.8037
# Epoch 11/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0893 - accuracy: 0.9685 - val_loss: 0.7389 - val_accuracy: 0.8052
# Epoch 12/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0769 - accuracy: 0.9754 - val_loss: 0.8364 - val_accuracy: 0.7998
# Epoch 13/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0629 - accuracy: 0.9768 - val_loss: 0.9038 - val_accuracy: 0.8021
# Epoch 14/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0595 - accuracy: 0.9800 - val_loss: 0.9580 - val_accuracy: 0.7985
# Epoch 15/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0515 - accuracy: 0.9822 - val_loss: 1.0739 - val_accuracy: 0.8004
# Epoch 16/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0424 - accuracy: 0.9850 - val_loss: 1.1320 - val_accuracy: 0.7973
# Epoch 17/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0435 - accuracy: 0.9836 - val_loss: 1.1587 - val_accuracy: 0.7930
# Epoch 18/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0354 - accuracy: 0.9879 - val_loss: 1.3095 - val_accuracy: 0.7940
# Epoch 19/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 1.3521 - val_accuracy: 0.7945
# Epoch 20/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0339 - accuracy: 0.9866 - val_loss: 1.3761 - val_accuracy: 0.7946
# Epoch 21/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0339 - accuracy: 0.9862 - val_loss: 1.4708 - val_accuracy: 0.7912
# Epoch 22/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0278 - accuracy: 0.9892 - val_loss: 1.5257 - val_accuracy: 0.7928
# Epoch 23/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0258 - accuracy: 0.9899 - val_loss: 1.5525 - val_accuracy: 0.7924
# Epoch 24/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0279 - accuracy: 0.9887 - val_loss: 1.5461 - val_accuracy: 0.7940
# Epoch 25/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0278 - accuracy: 0.9887 - val_loss: 1.7192 - val_accuracy: 0.7952
# Epoch 26/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0278 - accuracy: 0.9890 - val_loss: 1.7127 - val_accuracy: 0.7937
# Epoch 27/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0289 - accuracy: 0.9885 - val_loss: 1.8783 - val_accuracy: 0.7918
# Epoch 28/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0261 - accuracy: 0.9894 - val_loss: 1.7719 - val_accuracy: 0.7854
# Epoch 29/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0199 - accuracy: 0.9923 - val_loss: 1.9045 - val_accuracy: 0.7885
# Epoch 30/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0292 - accuracy: 0.9892 - val_loss: 1.9199 - val_accuracy: 0.7922
# Epoch 31/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0222 - accuracy: 0.9912 - val_loss: 1.9125 - val_accuracy: 0.7921
# Epoch 32/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0201 - accuracy: 0.9909 - val_loss: 1.9427 - val_accuracy: 0.7912
# Epoch 33/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0239 - accuracy: 0.9893 - val_loss: 1.9686 - val_accuracy: 0.7888
# Epoch 34/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0290 - accuracy: 0.9868 - val_loss: 1.8708 - val_accuracy: 0.7849
# Epoch 35/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0204 - accuracy: 0.9919 - val_loss: 1.9554 - val_accuracy: 0.7892
# Epoch 36/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0190 - accuracy: 0.9919 - val_loss: 2.0382 - val_accuracy: 0.7907
# Epoch 37/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0206 - accuracy: 0.9908 - val_loss: 2.1423 - val_accuracy: 0.7907
# Epoch 38/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0252 - accuracy: 0.9888 - val_loss: 2.1474 - val_accuracy: 0.7901
# Epoch 39/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0215 - accuracy: 0.9915 - val_loss: 2.0847 - val_accuracy: 0.7840
# Epoch 40/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0242 - accuracy: 0.9892 - val_loss: 2.2289 - val_accuracy: 0.7854
# Epoch 41/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0208 - accuracy: 0.9907 - val_loss: 2.3314 - val_accuracy: 0.7831
# Epoch 42/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0167 - accuracy: 0.9926 - val_loss: 2.1525 - val_accuracy: 0.7880
# Epoch 43/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0153 - accuracy: 0.9924 - val_loss: 2.3325 - val_accuracy: 0.7852
# Epoch 44/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0202 - accuracy: 0.9909 - val_loss: 2.2386 - val_accuracy: 0.7892
# Epoch 45/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0241 - accuracy: 0.9898 - val_loss: 2.2576 - val_accuracy: 0.7876
# Epoch 46/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0179 - accuracy: 0.9916 - val_loss: 2.2467 - val_accuracy: 0.7882
# Epoch 47/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0165 - accuracy: 0.9923 - val_loss: 2.3223 - val_accuracy: 0.7901
# Epoch 48/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0151 - accuracy: 0.9928 - val_loss: 2.5295 - val_accuracy: 0.7869
# Epoch 49/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0149 - accuracy: 0.9938 - val_loss: 2.5393 - val_accuracy: 0.7919
# Epoch 50/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0184 - accuracy: 0.9918 - val_loss: 2.6771 - val_accuracy: 0.7837

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h5")
