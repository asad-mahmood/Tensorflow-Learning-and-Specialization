# %%
import numpy as np

import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# --2021-03-03 01:30:11--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.13.80, 172.217.13.240, 172.217.15.80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.13.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2021-03-03 01:30:12 (107 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                12544
# _________________________________________________________________
# dense (Dense)                (None, 24)                1560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 30,129
# Trainable params: 30,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 43s 15ms/step - loss: 0.5395 - accuracy: 0.7005 - val_loss: 0.3885 - val_accuracy: 0.8204
# Epoch 2/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3558 - accuracy: 0.8369 - val_loss: 0.3783 - val_accuracy: 0.8247
# Epoch 3/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3312 - accuracy: 0.8511 - val_loss: 0.4024 - val_accuracy: 0.8144
# Epoch 4/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3143 - accuracy: 0.8613 - val_loss: 0.3716 - val_accuracy: 0.8350
# Epoch 5/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2919 - accuracy: 0.8727 - val_loss: 0.3710 - val_accuracy: 0.8363
# Epoch 6/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.2811 - accuracy: 0.8767 - val_loss: 0.3811 - val_accuracy: 0.8337
# Epoch 7/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2690 - accuracy: 0.8817 - val_loss: 0.3967 - val_accuracy: 0.8252
# Epoch 8/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2626 - accuracy: 0.8862 - val_loss: 0.3873 - val_accuracy: 0.8295
# Epoch 9/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2626 - accuracy: 0.8858 - val_loss: 0.3904 - val_accuracy: 0.8299
# Epoch 10/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2556 - accuracy: 0.8919 - val_loss: 0.4110 - val_accuracy: 0.8216
# Epoch 11/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2571 - accuracy: 0.8913 - val_loss: 0.4107 - val_accuracy: 0.8256
# Epoch 12/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2401 - accuracy: 0.8995 - val_loss: 0.4258 - val_accuracy: 0.8250
# Epoch 13/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2415 - accuracy: 0.8993 - val_loss: 0.4354 - val_accuracy: 0.8228
# Epoch 14/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2374 - accuracy: 0.9030 - val_loss: 0.4411 - val_accuracy: 0.8237
# Epoch 15/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2267 - accuracy: 0.9050 - val_loss: 0.4518 - val_accuracy: 0.8207
# Epoch 16/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2220 - accuracy: 0.9061 - val_loss: 0.4804 - val_accuracy: 0.8219
# Epoch 17/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.2065 - accuracy: 0.9136 - val_loss: 0.4641 - val_accuracy: 0.8170
# Epoch 18/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1988 - accuracy: 0.9169 - val_loss: 0.5154 - val_accuracy: 0.8140
# Epoch 19/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.1921 - accuracy: 0.9188 - val_loss: 0.5102 - val_accuracy: 0.8171
# Epoch 20/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1878 - accuracy: 0.9205 - val_loss: 0.5327 - val_accuracy: 0.8177
# Epoch 21/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1716 - accuracy: 0.9294 - val_loss: 0.5497 - val_accuracy: 0.8155
# Epoch 22/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1699 - accuracy: 0.9309 - val_loss: 0.5878 - val_accuracy: 0.8132
# Epoch 23/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1630 - accuracy: 0.9344 - val_loss: 0.5836 - val_accuracy: 0.8080
# Epoch 24/50
# 625/625 [==============================] - 8s 14ms/step - loss: 0.1629 - accuracy: 0.9334 - val_loss: 0.6457 - val_accuracy: 0.8103
# Epoch 25/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1506 - accuracy: 0.9377 - val_loss: 0.6407 - val_accuracy: 0.8077
# Epoch 26/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1438 - accuracy: 0.9429 - val_loss: 0.7511 - val_accuracy: 0.8047
# Epoch 27/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.1347 - accuracy: 0.9463 - val_loss: 0.7359 - val_accuracy: 0.8053
# Epoch 28/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1315 - accuracy: 0.9463 - val_loss: 0.7760 - val_accuracy: 0.8028
# Epoch 29/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1238 - accuracy: 0.9510 - val_loss: 0.8265 - val_accuracy: 0.8010
# Epoch 30/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1232 - accuracy: 0.9506 - val_loss: 0.9733 - val_accuracy: 0.7989
# Epoch 31/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1182 - accuracy: 0.9536 - val_loss: 0.8953 - val_accuracy: 0.8009
# Epoch 32/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1107 - accuracy: 0.9574 - val_loss: 0.8679 - val_accuracy: 0.7997
# Epoch 33/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.1039 - accuracy: 0.9589 - val_loss: 0.9522 - val_accuracy: 0.8037
# Epoch 34/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0970 - accuracy: 0.9633 - val_loss: 1.0204 - val_accuracy: 0.7985
# Epoch 35/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0980 - accuracy: 0.9622 - val_loss: 1.0583 - val_accuracy: 0.7992
# Epoch 36/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0952 - accuracy: 0.9645 - val_loss: 1.1051 - val_accuracy: 0.7988
# Epoch 37/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0851 - accuracy: 0.9675 - val_loss: 1.1238 - val_accuracy: 0.7942
# Epoch 38/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.0809 - accuracy: 0.9695 - val_loss: 1.2189 - val_accuracy: 0.7942
# Epoch 39/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0807 - accuracy: 0.9687 - val_loss: 1.2486 - val_accuracy: 0.7916
# Epoch 40/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0807 - accuracy: 0.9697 - val_loss: 1.2019 - val_accuracy: 0.7889
# Epoch 41/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.0767 - accuracy: 0.9707 - val_loss: 1.3310 - val_accuracy: 0.8012
# Epoch 42/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0741 - accuracy: 0.9731 - val_loss: 1.3644 - val_accuracy: 0.7909
# Epoch 43/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.0658 - accuracy: 0.9764 - val_loss: 1.4736 - val_accuracy: 0.7980
# Epoch 44/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0633 - accuracy: 0.9755 - val_loss: 1.4193 - val_accuracy: 0.7909
# Epoch 45/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0616 - accuracy: 0.9771 - val_loss: 1.5885 - val_accuracy: 0.7931
# Epoch 46/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.0592 - accuracy: 0.9765 - val_loss: 1.5731 - val_accuracy: 0.7866
# Epoch 47/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0643 - accuracy: 0.9743 - val_loss: 1.6017 - val_accuracy: 0.7958
# Epoch 48/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0662 - accuracy: 0.9731 - val_loss: 1.5348 - val_accuracy: 0.7858
# Epoch 49/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0624 - accuracy: 0.9768 - val_loss: 1.5980 - val_accuracy: 0.7915
# Epoch 50/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.0542 - accuracy: 0.9803 - val_loss: 1.6656 - val_accuracy: 0.7831

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h5")
