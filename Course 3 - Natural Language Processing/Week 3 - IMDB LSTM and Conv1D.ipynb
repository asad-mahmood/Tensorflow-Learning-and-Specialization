# %% [markdown]
# # IMDB Dataset LSTM and Conv1D

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.4.1

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteG7H95A/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteG7H95A/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteG7H95A/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 48s 19ms/step - loss: 0.6471 - accuracy: 0.5824 - val_loss: 0.3837 - val_accuracy: 0.8236
# Epoch 2/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.3144 - accuracy: 0.8707 - val_loss: 0.3625 - val_accuracy: 0.8373
# Epoch 3/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.2307 - accuracy: 0.9102 - val_loss: 0.4120 - val_accuracy: 0.8315
# Epoch 4/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1668 - accuracy: 0.9378 - val_loss: 0.4235 - val_accuracy: 0.8272
# Epoch 5/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1305 - accuracy: 0.9540 - val_loss: 0.5522 - val_accuracy: 0.8220
# Epoch 6/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0972 - accuracy: 0.9661 - val_loss: 0.6113 - val_accuracy: 0.8224
# Epoch 7/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0654 - accuracy: 0.9778 - val_loss: 0.6429 - val_accuracy: 0.8196
# Epoch 8/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0438 - accuracy: 0.9862 - val_loss: 0.7305 - val_accuracy: 0.8130
# Epoch 9/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0258 - accuracy: 0.9926 - val_loss: 0.8191 - val_accuracy: 0.8057
# Epoch 10/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.9107 - val_accuracy: 0.8072
# Epoch 11/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.9259 - val_accuracy: 0.8121
# Epoch 12/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.9962 - val_accuracy: 0.8033
# Epoch 13/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0171 - accuracy: 0.9939 - val_loss: 1.0927 - val_accuracy: 0.8096
# Epoch 14/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 1.0351 - val_accuracy: 0.8096
# Epoch 15/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 1.1115 - val_accuracy: 0.8069
# Epoch 16/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 1.2331 - val_accuracy: 0.8091
# Epoch 17/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 1.1722 - val_accuracy: 0.8040
# Epoch 18/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 1.2087 - val_accuracy: 0.8017
# Epoch 19/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 1.3244 - val_accuracy: 0.8103
# Epoch 20/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 1.5811 - val_accuracy: 0.7972
# Epoch 21/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 1.3074 - val_accuracy: 0.8020
# Epoch 22/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 1.3740 - val_accuracy: 0.8090
# Epoch 23/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 1.3218 - val_accuracy: 0.8102
# Epoch 24/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 1.4251 - val_accuracy: 0.8052
# Epoch 25/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 1.4351 - val_accuracy: 0.8004
# Epoch 26/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 1.5402 - val_accuracy: 0.7930
# Epoch 27/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 1.4339 - val_accuracy: 0.8103
# Epoch 28/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 1.4673 - val_accuracy: 0.8096
# Epoch 29/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.6938 - val_accuracy: 0.7885
# Epoch 30/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 1.4780 - val_accuracy: 0.8035
# Epoch 31/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 1.4713 - val_accuracy: 0.8052
# Epoch 32/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.4490 - val_accuracy: 0.8037
# Epoch 33/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.6060 - val_accuracy: 0.8007
# Epoch 34/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.6392 - val_accuracy: 0.8062
# Epoch 35/50
# 782/782 [==============================] - 15s 19ms/step - loss: 5.4196e-04 - accuracy: 0.9999 - val_loss: 1.6364 - val_accuracy: 0.7980
# Epoch 36/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.5249 - val_accuracy: 0.8114
# Epoch 37/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 1.6200 - val_accuracy: 0.8079
# Epoch 38/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 1.6949 - val_accuracy: 0.8099
# Epoch 39/50
# 782/782 [==============================] - 13s 17ms/step - loss: 7.0360e-05 - accuracy: 1.0000 - val_loss: 1.7342 - val_accuracy: 0.8103
# Epoch 40/50
# 782/782 [==============================] - 14s 17ms/step - loss: 2.0301e-05 - accuracy: 1.0000 - val_loss: 1.7677 - val_accuracy: 0.8106
# Epoch 41/50
# 782/782 [==============================] - 14s 19ms/step - loss: 1.4500e-05 - accuracy: 1.0000 - val_loss: 1.8061 - val_accuracy: 0.8114
# Epoch 42/50
# 782/782 [==============================] - 15s 19ms/step - loss: 9.9140e-06 - accuracy: 1.0000 - val_loss: 1.8484 - val_accuracy: 0.8119
# Epoch 43/50
# 782/782 [==============================] - 15s 19ms/step - loss: 7.4297e-06 - accuracy: 1.0000 - val_loss: 1.8940 - val_accuracy: 0.8120
# Epoch 44/50
# 782/782 [==============================] - 14s 18ms/step - loss: 5.2030e-06 - accuracy: 1.0000 - val_loss: 1.9441 - val_accuracy: 0.8118
# Epoch 45/50
# 782/782 [==============================] - 14s 18ms/step - loss: 3.6051e-06 - accuracy: 1.0000 - val_loss: 1.9962 - val_accuracy: 0.8115
# Epoch 46/50
# 782/782 [==============================] - 14s 17ms/step - loss: 2.5622e-06 - accuracy: 1.0000 - val_loss: 2.0499 - val_accuracy: 0.8119
# Epoch 47/50
# 782/782 [==============================] - 14s 18ms/step - loss: 1.7391e-06 - accuracy: 1.0000 - val_loss: 2.1083 - val_accuracy: 0.8113
# Epoch 48/50
# 782/782 [==============================] - 15s 19ms/step - loss: 1.2006e-06 - accuracy: 1.0000 - val_loss: 2.1658 - val_accuracy: 0.8114
# Epoch 49/50
# 782/782 [==============================] - 15s 19ms/step - loss: 7.7803e-07 - accuracy: 1.0000 - val_loss: 2.2269 - val_accuracy: 0.8114
# Epoch 50/50
# 782/782 [==============================] - 14s 18ms/step - loss: 5.3155e-07 - accuracy: 1.0000 - val_loss: 2.2877 - val_accuracy: 0.8112

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Definition with Conv1D
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________
